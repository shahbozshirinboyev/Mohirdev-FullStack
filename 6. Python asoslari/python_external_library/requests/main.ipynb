# %%
# modulni o'rnatib olamiz
# %pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\shahb\appdata\local\programs\python\python313\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shahb\appdata\local\programs\python\python313\lib\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shahb\appdata\local\programs\python\python313\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shahb\appdata\local\programs\python\python313\lib\site-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shahb\appdata\local\programs\python\python313\lib\site-packages (from requests) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from pprint import pprint

sahifa = 'https://os-services.uz'
r = requests.get(sahifa)

pprint(r.text)
# Out:
# ('<!DOCTYPE html>\n'
#  '<html class="no-js" lang="uz">\n'
#  '\n'
#  '<head>\n'
#  '    <meta charset="utf-8">\n'
#  '    <meta http-equiv="x-ua-compatible" content="ie=edge">\n'
#  '    <title>OS//Services | Kompyuter Xizmatlari</title>\n'
#  '    <meta name="description" content="Butun O\'zbekiston bo\'ylab - '
#  'Kompyuter Xizmatlari | Operatsion Tizimlar | Dasturlar | Drayverlar | '
#  'Paketlar">\n'
#  '    <meta name="viewport" content="width=device-width, initial-scale=1">\n'
#  '    <link rel="shortcut icon" type="image/x-icon" '
#  'href="assets/images/title.svg">\n'
#  '    <!-- ========================= CSS here ========================= -->\n'
#  '    <link rel="stylesheet" href="assets/css/bootstrap.min.css">\n'
#  '    <link rel="stylesheet" href="assets/css/LineIcons.2.0.css">\n'
#  '    <link rel="stylesheet" href="assets/css/animate.css">\n'
#  '    <link rel="stylesheet" href="assets/css/tiny-slider.css">\n'
#  '    <link rel="stylesheet" href="assets/css/glightbox.min.css">\n'
#  '    <link rel="stylesheet" href="assets/css/main.css">\n'
#  '    <link rel="stylesheet" href="assets/css/wrapper.css">\n'
#  '\n'
#  '    <style>\n'
#  '        .object-fit-cover {\n'
#  '          object-fit: cover;\n'
#  '        }\n'
#  '    </style>\n'
#  '</head>\n'
#  '\n'
#  '<body>\n'
#  '    <!-- Preloader -->\n'
#  '    <div class="preloader">\n'
#  '        <div class="preloader-inner">\n'
#  '            <div class="preloader-icon">\n'
#  '                <span></span>\n'
#  '                <span></span>\n'
#  '            </div>\n'
#  '        </div>\n'
#  '    </div>\n'
#  '    <!-- /End Preloader -->\n'
#  '\n'
#  '    <!-- Start Navbar -->\n'
#  '    <header class="header navbar-area">\n'
#  '        <div class="container">\n'
#  '            <div class="row align-items-center">\n'
#  '                <div class="col-lg-12">\n'
#  '                    <div class="nav-inner">\n'
#  '                        <!-- Start Navbar -->\n'
#  '                        <nav class="navbar navbar-expand-lg">\n'
#  '                            <a class="navbar-brand" href="index.html">\n'
#  '                                <img src="assets/images/logo/white.svg" '
#  'alt="OS//Services">\n'
#  '                            </a>\n'
#  '                            <button class="navbar-toggler mobile-menu-btn" '
#  'type="button" data-bs-toggle="collapse"\n'
#  '                                data-bs-target="#navbarSupportedContent" '
#  'aria-controls="navbarSupportedContent"\n'
#  '                                aria-expanded="false" aria-label="Toggle '
#  'navigation">\n'
#  '                                <span class="toggler-icon"></span>\n'
#  '                                <span class="toggler-icon"></span>\n'
#  '                                <span class="toggler-icon"></span>\n'
#  '                            </button>\n'
#  '                            <div class="collapse navbar-collapse '
#  'sub-menu-bar" id="navbarSupportedContent">\n'
#  '                                <ul id="nav" class="navbar-nav ms-auto">\n'
#  '                                    <li class="nav-item">\n'
#  '                                        <a href="#monobloklar" '
#  'class="page-scroll active" aria-label="Toggle navigation"\n'
#  '                                            style="text-transform: '
#  'uppercase;">Monobloklar</a>\n'
#  '                                    </li>\n'
#  '                                    <li class="nav-item">\n'
#  '                                        <a href="#operatsion" '
#  'class="page-scroll active" aria-label="Toggle navigation"\n'
#  '                                            style="text-transform: '
#  'uppercase;">Operatsion tizimlar</a>\n'
#  '                                    </li>\n'
#  '                                    <li class="nav-item">\n'
#  '                                        <a href="#features" '
#  'class="page-scroll" aria-label="Toggle navigation"\n'
#  '                                            style="text-transform: '
#  'uppercase;">Dasturlar</a>\n'
#  '                                    </li>\n'
#  '                                    <li class="nav-item">\n'
#  '                                        <a href="#drayverlar" '
#  'class="page-scroll"\n'
#  '                                            style="text-transform: '
#  'uppercase;">Drayverlar</a>\n'
#  '                                    </li>\n'
#  '                                    <!-- <li class="nav-item">\n'
#  '                                        <a href="#pricing" '
#  'class="page-scroll" aria-label="Toggle navigation"\n'
#  '                                            style="text-transform: '
#  'uppercase;">Paketlar</a>\n'
#  '                                    </li> -->\n'
#  '                                </ul>\n'
#  '                            </div> <!-- navbar collapse -->\n'
#  '                            <div class="button add-list-button">\n'
#  '                                <a href="tel:+998930091166" class="btn">+998 '
#  '(93) 009 11 66</a>\n'
#  '                            </div>\n'
#  '                        </nav>\n'
#  '                        <!-- End Navbar -->\n'
#  '                    </div>\n'
#  '                </div>\n'
#  '            </div> <!-- row -->\n'
#  '        </div> <!-- container -->\n'
#  '    </header>\n'
#  '    <!-- End Navbar -->\n'
#  '\n'
#  '    <!-- Start Home -->\n'
#  '    <section id="home" class="hero-area">\n'
#  '        <div class="container">\n'
#  '            <div class="row align-items-center justify-content-center">\n'
#  '                <div class="col-lg-5 col-md-12 col-12">\n'
#  '                    <div class="hero-content">\n'
#  '                        <h1 class="wow fadeInLeft" '
#  'data-wow-delay=".4s">Qulay <span>muhitda</span> va <span>vaqtda</span> '
#  'xizmatlarimizdan foydalaning!</h1>\n'
#  '                        <p class="wow fadeInLeft" '
#  'data-wow-delay=".6s">Toshkent shahrining istalgan nuqtasiga 1 soat ichida '
#  'yetib bora olamiz!</p>\n'
#  '                        <div class="button wow fadeInLeft" '
#  'data-wow-delay=".8s">\n'
#  '                            <a href="tel:+998930091166" class="btn"><i '
#  'class="lni lni-phone"></i>93 009 11 66</a>\n'
#  '                            <a href="https://t.me/sh_shirinboyev" class="btn '
#  'btn-alt"><i class="lni lni-telegram-original"></i>Telegram</a>\n'
#  '                        </div>\n'
#  '                    </div>\n'
#  '                </div>\n'
#  '                <div class="col-lg-7 col-md-12 col-12">\n'
#  '                    <div class="hero-image wow fadeInRight" '
#  'data-wow-delay=".4s">\n'
#  '                        <img src="assets/images/hero/header-min.png" '
#  'alt="#">\n'
#  '                    </div>\n'
#  '                </div>\n'
#  '            </div>\n'
#  '        </div>\n'
#  '    </section>\n'
#  '    <!--/ End Home -->\n'
#  '\n'
#  '    <!--  Monoblok Batafsil Modal -->\n'
#  '    <div class="modal fade" id="batafsilModal" tabindex="-1" '
#  'aria-labelledby="batafsilModalLabel" aria-hidden="true">\n'
#  '        <div class="modal-dialog modal-dialog-centered '
#  'modal-dialog-scrollable modal-lg">\n'
#  '            <div class="modal-content">\n'
#  '                <div class="modal-header">\n'
#  '                    <h5 class="modal-title" '
#  'id="batafsilModalLabel">Batafsil</h5>\n'
#  '                    <button type="button" class="btn-close" '
#  'data-bs-dismiss="modal" aria-label="Close"></button>\n'
#  '                </div>\n'
#  '                <div class="modal-body">\n'
#  '                    <div id="carouselExampleControls" class="carousel slide '
#  'mb-3" data-bs-ride="carousel" style="height: 350px;">\n'
#  '                        <div class="carousel-inner h-100 d-flex '
#  'align-items-center">\n'
#  '                            <div class="carousel-item active">\n'
#  '                                <img '
#  'src="https://s3p.kattabozor.uz/ri/bf132ede2bd127ec3c8800e889824410a9252f8b97c8b934839fb9372c76c86c_obsqaS_640l.jpg" '
#  'class="d-block w-50 mx-auto" alt="...">\n'
#  '                            </div>\n'
#  '                            <div class="carousel-item">\n'
#  '                                <img '
#  'src="https://s3p.kattabozor.uz/ri/5cd83c31bb679c5d5cfdc8fc17607d0a9dbaeabf2af37ba6f6027f6b9c296f2a_GdmHtJ_640l.jpg" '
#  'class="d-block w-50 mx-auto" alt="...">\n'
#  '                            </div>\n'
#  '                            <div class="carousel-item">\n'
#  '                                <img '
#  'src="https://s3p.kattabozor.uz/ri/fd31e6b226d5edace7d3d4f947cedc1be21c03f91bfefe83293f6bbe8f0bf58a_OpMlKo_640l.jpg" '
#  'class="d-block w-50 mx-auto" alt="...">\n'
#  '                            </div>\n'
#  '                            <div class="carousel-item">\n'
#  '                                <img '
#  'src="https://s3p.kattabozor.uz/ri/5ccb864d99c074db0765802de5f125d27684d5ff702e6b5c3fd52c4c5a959a84_7wWE6x_640l.jpg" '
#  'class="d-block w-50 mx-auto" alt="...">\n'
#  '                            </div>\n'
#  '                        </div>\n'
#  '                        <button class="carousel-control-prev" type="button" '
#  'data-bs-target="#carouselExampleControls" data-bs-slide="prev">\n'
#  '                          <span class="carousel-control-prev-icon" '
#  'aria-hidden="true" style="filter: invert(1);" ></span>\n'
#  '                          <span class="visually-hidden">Previous</span>\n'
#  '                        </button>\n'
#  '                        <button class="carousel-control-next" type="button" '
#  'data-bs-target="#carouselExampleControls" data-bs-slide="next">\n'
#  '                          <span class="carousel-control-next-icon" '
#  'aria-hidden="true" style="filter: invert(1);" ></span>\n'
#  '                          <span class="visually-hidden">Next</span>\n'
#  '                        </button>\n'
#  '                    </div>\n'
#  '\n'
#  '                    <table class="table table-striped mb-3">\n'
#  '                        <thead>\n'
#  '                          <tr>\n'
#  '                            <th style="width: 40%;">Xususiyat</th>\n'
#  '                            <th style="width: 60%;">Qiymat</th>\n'
#  '                          </tr>\n'
#  '                        </thead>\n'
#  '                        <tbody>\n'
#  '                          <tr><td>Vazn</td><td>4.0 ÐºÐ³</td></tr>\n'
#  '                          <tr><td>Qalinligi</td><td>3.71 Ñ\x81Ð¼</td></tr>\n'
#  "                          <tr><td>Bo'yi</td><td>37.96 Ñ\x81Ð¼</td></tr>\n"
#  '                          <tr><td>Kengligi</td><td>48.99 Ñ\x81Ð¼</td></tr>\n'
#  '                          <tr><td>Oâ\x80\x98rnatilgan imkoniyatlar va '
#  'funksional</td><td>Ð²ÐµÐ±-ÐºÐ°Ð¼ÐµÑ\x80Ð°, Ð²Ñ\x81Ñ\x82Ñ\x80Ð¾ÐµÐ½Ð½Ñ\x8bÐ¹ '
#  'Ð¼Ð¸ÐºÑ\x80Ð¾Ñ\x84Ð¾Ð½, ÐºÐ°Ñ\x80Ð´Ñ\x80Ð¸Ð´ÐµÑ\x80, '
#  'Ñ\x81Ñ\x82ÐµÑ\x80ÐµÐ¾Ð·Ð²Ñ\x83Ðº</td></tr>\n'
#  '                          '
#  '<tr><td>Periferiya</td><td>Ð±ÐµÑ\x81Ð¿Ñ\x80Ð¾Ð²Ð¾Ð´Ð½Ð°Ñ\x8f '
#  'ÐºÐ»Ð°Ð²Ð¸Ð°Ñ\x82Ñ\x83Ñ\x80Ð°, Ð±ÐµÑ\x81Ð¿Ñ\x80Ð¾Ð²Ð¾Ð´Ð½Ð°Ñ\x8f '
#  'Ð¼Ñ\x8bÑ\x88Ñ\x8c</td></tr>\n'
#  '                          <tr><td>USB portlar umumiy '
#  'soni</td><td>4</td></tr>\n'
#  '                          <tr><td>Portlar va interfeyslar</td><td>Ethernet '
#  '(RJ-45), USB 2.0 Type-A, USB 3.2 Gen 1 Type-A, Ð²Ñ\x85'
#  'Ð¾Ð´ HDMI, Ð²Ñ\x8bÑ\x85'
#  'Ð¾Ð´ Ð°Ñ\x83Ð´Ð¸Ð¾/Ð½Ð°Ñ\x83Ñ\x88Ð½Ð¸ÐºÐ¸</td></tr>\n'
#  '                          <tr><td>Wi-Fi '
#  'standarti</td><td>802.11ax</td></tr>\n'
#  '                          <tr><td>Simsiz interfeyslar</td><td>Bluetooth, '
#  'Wi-Fi</td></tr>\n'
#  '                          <tr><td>SSD xotira hajmlari</td><td>256 '
#  'Ð\x93Ð\x91</td></tr>\n'
#  '                          <tr><td>HDD xotira hajmlari</td><td>1 '
#  'Ð¢Ð\x91</td></tr>\n'
#  '                          <tr><td>Operativ xotira chastotasi</td><td>3200 '
#  'Ð\x9cÐ\x93Ñ\x86</td></tr>\n'
#  '                          <tr><td>Operativ xotira hajmi</td><td>4 '
#  'Ð\x93Ð\x91, 8 Ð\x93Ð\x91, 16 Ð\x93Ð\x91</td></tr>\n'
#  '                          <tr><td>Operativ xotira turi</td><td>SO-DIMM '
#  'DDR4</td></tr>\n'
#  '                          <tr><td>Videokarta</td><td>Intel UHD Graphics, '
#  'Intel Iris Xe Graphics</td></tr>\n'
#  '                          <tr><td>Protsessor lineykasi</td><td>Intel Core '
#  'i3, Intel Core i5</td></tr>\n'
#  '                          <tr><td>Ekran matritsasi '
#  'turi</td><td>IPS</td></tr>\n'
#  '                          <tr><td>Ekran qoplamasi '
#  'turi</td><td>Ð¼Ð°Ñ\x82Ð¾Ð²Ñ\x8bÐ¹</td></tr>\n'
#  '                          <tr><td>Ekran piksellari '
#  'oâ\x80\x98lchamlari</td><td>1920x1080</td></tr>\n'
#  '                          <tr><td>Ekran '
#  'oâ\x80\x98lchami</td><td>24"</td></tr>\n'
#  '                          <tr><td>Brend</td><td>AkmalovichÂ®</td></tr>\n'
#  '                        </tbody>\n'
#  '                    </table>\n'
#  '\n'
#  '                    <div class="alert alert-info" role="alert">\n'
#  '                        <p class="text-gray fs-5 fw-bolder mb-2">Tavsif</p>\n'
#  '                        <p>Hammasi bir joyda. Aspire C22 monobloki juda '
#  'ixcham dizaynga ega. Ultra yupqa korpus kundalik ishlarga yetadigan optimal '
#  'quvvat uchun Intel protsessoriga ega. Full HD displey va Full HD 1080p '
#  "veb-kamera zamonaviy videoqo'ng'iroqlar uchun zarur bo'lgan aniq va tiniq "
#  "tasvirlarni taqdim etadi. HDMI porti qo'shimcha displeyni ulash imkonini "
#  'beradi, USB portlari tashqi qurilmalarni ulash imkonini beradi va simsiz '
#  'tarmoq adapteri Wi-Fi 5 (802.11ac) standarti yordamida Internetga ulanish '
#  'imkonini beradi.</p>\n'
#  '                    </div>\n'
#  '                </div>\n'
#  '                <!-- <div class="modal-footer">\n'
#  '                    <button type="button" class="btn btn-secondary" '
#  'data-bs-dismiss="modal">Close</button>\n'
#  '                    <button type="button" class="btn btn-primary">Save '
#  'changes</button>\n'
#  '                </div> -->\n'
#  '            </div>\n'
#  '        </div>\n'
#  '    </div>\n'
#  '    <!--/ Monoblok Batafsil Modal -->\n'
#  '\n'
#  '    <!--  Monoblok Order Modal -->\n'
#  '    <div class="modal fade" id="monoblokModal" tabindex="-1" '
#  'aria-labelledby="monoblokModalLabel" data-bs-backdrop="static" '
#  'aria-hidden="true">\n'
#  '        <div class="modal-dialog modal-dialog-centered '
#  'modal-dialog-scrollable">\n'
#  '            <div class="modal-content">\n'
#  '                <div class="modal-header">\n'
#  '                    <div>\n'
#  '                        <h5 class="modal-title fs-6" '
#  'id="monoblokModalLabel">Buyurtmani rasmiylashtirish</h5>\n'
#  '                    </div>\n'
#  '                    <button type="button" class="btn-close" '
#  'data-bs-dismiss="modal" aria-label="Close"></button>\n'
#  '                </div>\n'
#  '                <div class="modal-body px-4">\n'
#  '                    <div class="d-flex justify-content-start '
#  'align-items-center gap-3">\n'
#  '                        <img src="/assets/images/monobloklar/monoblok_1.jpg" '
#  'alt="monoblok_1" class="monoblok_brand">\n'
#  '\n'
#  '                        <div>\n'
#  '                            <h5 class="modal-title fs-6" '
#  'id="monoblokModalLabel">Monoblok 24\'\' Flat</h5>\n'
#  '                            <span class="fw-light" style="font-size: '
#  '12px;">H510 (D238)</span>\n'
#  '                        </div>\n'
#  '                    </div>\n'
#  '                    <form>\n'
#  '                        <div class="mb-2 mt-4">\n'
#  '                            <label for="exampleInputName" class="form-label '
#  'mb-0 fw-normal">Ismingiz:</label>\n'
#  '                            <input required type="text" class="form-control" '
#  'id="exampleInputName" placeholder="Jahongir">\n'
#  '                        </div>\n'
#  '                        <label for="exampleInputNumber" class="form-label '
#  'mb-0 fw-normal">Telfon raqamingiz:</label>\n'
#  '                        <div class="input-group mb-5">\n'
#  '                            <span class="input-group-text" '
#  'id="basic-number">+998</span>\n'
#  '                            <input required type="text" class="form-control" '
#  'id="exampleInputNumber" placeholder="88 123 45 67" aria-label="number" '
#  'aria-describedby="basic-number"> </div>\n'
#  '                        <div class="d-flex gap-2 justify-content-end">\n'
#  '                            <button type="button" class="btn btn-secondary" '
#  'data-bs-dismiss="modal">Bekor qilish</button>\n'
#  '                            <button type="submit" class="btn '
#  'btn-primary">Buyurtma qoldirish</button>\n'
#  '                        </div>\n'
#  '                    </form>\n'
#  '                </div>\n'
#  '            </div>\n'
#  '        </div>\n'
#  '    </div>\n'
#  '    <!--/ Monoblok Order Modal -->\n'
#  '\n'
#  '    <!-- Monobloklar start -->\n'
#  '    <section id="monobloklar" class="features section" '
#  'style="padding-bottom: 0px;">\n'
#  '        <div class="container">\n'
#  '            <div class="row">\n'
#  '                <div class="col-12">\n'
#  '                    <div class="section-title">\n'
#  '\n'
#  '                        <div class="alert alert-warning" role="alert">\n'
#  '                            Bu boâ\x80\x98lim hozirda test rejimida '
#  'ishlamoqda. Hozircha buyurtmalar qabul qilinmaydi!\n'
#  '                        </div>\n'
#  '\n'
#  '                        <h2 style="text-transform: uppercase; color: '
#  '#3ba1e7;">Monobloklar</h2>\n'
#  "                        <p>O'zingiz uchun qulay muhitni yarating va "
#  'muammolarni bir zumda hal eting!<br>Kuchli monoblokga bugunoq buyurtma '
#  'bering.</p>\n'
#  '                    </div>\n'
#  '                </div>\n'
#  '            </div>\n'
#  '            <div class="row">\n'
#  '\n'
#  '                <div class="col-lg-4 col-md-6 col-12">\n'
#  '                    <div class="single-feature wow fadeInUp p-4 p-md-3 '
#  'p-xl-4" data-wow-delay=".2s">\n'
#  '                        <img class="w-75 d-block mx-auto mb-4 '
#  'object-fit-cover" style="height: 180px;" '
#  'src="./assets/images/monobloklar/monoblok_1.jpg" alt="monoblok_1">\n'
#  "                        <h5>Monoblok 24'' Flat</h5>\n"
#  '                        <h6>H510 (D238)</h6>\n'
#  '                        <br>\n'
#  '                        <h6 class="text-decoration-line-through '
#  'text-danger">3 900 000 so\'m</h6>\n'
#  '                        <h4 class="text-primary">3 200 000 so\'m</h4>\n'
#  '\n'
#  '                        <div class="table-content mt-3">\n'
#  '                            <ul class="table-list table-list-nth mb-3">\n'
#  '                                <li>\n'
#  '                                  <svg xmlns="http://www.w3.org/2000/svg" '
#  'width="18" height="18" fill="currentColor" class="bi bi-cpu" viewBox="0 0 16 '
#  '16">\n'
#  '                                    <path d="M5 0a.5.5 0 0 1 '
#  '.5.5V2h1V.5a.5.5 0 0 1 1 0V2h1V.5a.5.5 0 0 1 1 0V2h1V.5a.5.5 0 0 1 1 0V2A2.5 '
#  '2.5 0 0 1 14 4.5h1.5a.5.5 0 0 1 0 1H14v1h1.5a.5.5 0 0 1 0 1H14v1h1.5a.5.5 0 '
#  '0 1 0 1H14v1h1.5a.5.5 0 0 1 0 1H14a2.5 2.5 0 0 1-2.5 2.5v1.5a.5.5 0 0 1-1 '
#  '0V14h-1v1.5a.5.5 0 0 1-1 0V14h-1v1.5a.5.5 0 0 1-1 0V14h-1v1.5a.5.5 0 0 1-1 '
#  '0V14A2.5 2.5 0 0 1 2 11.5H.5a.5.5 0 0 1 0-1H2v-1H.5a.5.5 0 0 1 '
#  '0-1H2v-1H.5a.5.5 0 0 1 0-1H2v-1H.5a.5.5 0 0 1 0-1H2A2.5 2.5 0 0 1 4.5 '
#  '2V.5A.5.5 0 0 1 5 0m-.5 3A1.5 1.5 0 0 0 3 4.5v7A1.5 1.5 0 0 0 4.5 13h7a1.5 '
#  '1.5 0 0 0 1.5-1.5v-7A1.5 1.5 0 0 0 11.5 3zM5 6.5A1.5 1.5 0 0 1 6.5 5h3A1.5 '
#  '1.5 0 0 1 11 6.5v3A1.5 1.5 0 0 1 9.5 11h-3A1.5 1.5 0 0 1 5 9.5zM6.5 6a.5.5 0 '
#  '0 0-.5.5v3a.5.5 0 0 0 .5.5h3a.5.5 0 0 0 .5-.5v-3a.5.5 0 0 0-.5-.5z"/>\n'
#  '                                  </svg>\n'
#  '                                  <b>CPU:</b> Core i3-10400</li>\n'
#  '                                <li>\n'
#  '                                  <svg xmlns="http://www.w3.org/2000/svg" '
#  'width="18" height="18" fill="currentColor" class="bi bi-memory" viewBox="0 0 '
#  '16 16">\n'
#  '                                    <path d="M1 3a1 1 0 0 0-1 1v8a1 1 0 0 0 '
#  '1 1h4.586a1 1 0 0 0 .707-.293l.353-.353a.5.5 0 0 1 .708 0l.353.353a1 1 0 0 0 '
#  '.707.293H15a1 1 0 0 0 1-1V4a1 1 0 0 0-1-1zm.5 1h3a.5.5 0 0 1 .5.5v4a.5.5 0 0 '
#  '1-.5.5h-3a.5.5 0 0 1-.5-.5v-4a.5.5 0 0 1 .5-.5m5 0h3a.5.5 0 0 1 .5.5v4a.5.5 '
#  '0 0 1-.5.5h-3a.5.5 0 0 1-.5-.5v-4a.5.5 0 0 1 .5-.5m4.5.5a.5.5 0 0 1 '
#  '.5-.5h3a.5.5 0 0 1 .5.5v4a.5.5 0 0 1-.5.5h-3a.5.5 0 0 1-.5-.5zM2 '
#  '10v2H1v-2zm2 0v2H3v-2zm2 0v2H5v-2zm3 0v2H8v-2zm2 0v2h-1v-2zm2 0v2h-1v-2zm2 '
#  '0v2h-1v-2z"/>\n'
#  '                                  </svg>\n'
#  '                                  <b>RAM:</b> 8 GB</li>\n'
#  '                                <li>\n'
#  '                                  <svg xmlns="http://www.w3.org/2000/svg" '
#  'width="18" height="18" fill="currentColor" class="bi bi-nvme" viewBox="0 0 '
#  '16 16">\n'
#  '                                    <path d="M1.5 4.5A.5.5 0 0 1 2 '
#  '4h13.5a.5.5 0 0 1 .5.5V7a.5.5 0 0 1-.5.5.5.5 0 0 0 0 1 .5.5 0 0 1 '
#  '.5.5v2.5a.5.5 0 0 1-.5.5H2a.5.5 0 0 1-.5-.5h-1A.5.5 0 0 1 0 11V7.5A.5.5 0 0 '
#  '1 .5 7h1a.25.25 0 0 0 0-.5h-1A.5.5 0 0 1 0 6V5a.5.5 0 0 1 .5-.5zm1 .5a.5.5 0 '
#  '0 1-.5.5h-.5a1.25 1.25 0 1 1 0 2.5H1v2.5h1a.5.5 0 0 1 .5.5H15V9.415a1.5 1.5 '
#  '0 0 1 0-2.83V5z"/>\n'
#  '                                    <path d="M4 6.5a.5.5 0 0 1 .5-.5h2a.5.5 '
#  '0 0 1 .5.5v3a.5.5 0 0 1-.5.5h-2a.5.5 0 0 1-.5-.5zM5 7v2h1V7zm3-.5a.5.5 0 0 1 '
#  '.5-.5h4a.5.5 0 0 1 .5.5v3a.5.5 0 0 1-.5.5h-4a.5.5 0 0 1-.5-.5zM9 '
#  '7v2h3V7z"/>\n'
#  '                                  </svg>\n'
#  '                                  <b>SSD:</b> 512 GB\n'
#  '                                </li>\n'
#  '                            </ul>\n'
#  '                            <div class="d-flex justify-content-between '
#  'align-items-center gap-3">\n'
#  '                                <button data-bs-toggle="modal" '
#  'data-bs-target="#batafsilModal" class="btn btn-primary w-100 d-flex '
#  'justify-content-center align-items-center gap-2">\n'
#  '                                    <svg xmlns="http://www.w3.org/2000/svg" '
#  'width="16" height="16" fill="currentColor" class="bi bi-info-circle" '
#  'viewBox="0 0 16 16">\n'
#  '                                        <path d="M8 15A7 7 0 1 1 8 1a7 7 0 0 '
#  '1 0 14m0 1A8 8 0 1 0 8 0a8 8 0 0 0 0 16"/>\n'
#  '                                        <path d="m8.93 '
#  '6.588-2.29.287-.082.38.45.083c.294.07.352.176.288.469l-.738 '
#  '3.468c-.194.897.105 1.319.808 1.319.545 0 1.178-.252 '
#  '1.465-.598l.088-.416c-.2.176-.492.246-.686.246-.275 0-.375-.193-.304-.533zM9 '
#  '4.5a1 1 0 1 1-2 0 1 1 0 0 1 2 0"/>\n'
#  '                                    </svg>\n'
#  '                                    <span '
#  'class="text-nowrap">Batafsil</span>\n'
#  '                                </button>\n'
#  '                                <button data-bs-toggle="modal" '
#  'data-bs-target="#monoblokModal" class="btn btn-primary w-100 d-flex '
#  'justify-content-center align-items-center gap-2">\n'
#  '                                    <svg xmlns="http://www.w3.org/2000/svg" '
#  'width="16" height="16" fill="currentColor" class="bi bi-cart4" viewBox="0 0 '
#  '16 16">\n'
#  '                                        <path d="M0 2.5A.5.5 0 0 1 .5 '
#  '2H2a.5.5 0 0 1 .485.379L2.89 4H14.5a.5.5 0 0 1 .485.621l-1.5 6A.5.5 0 0 1 13 '
#  '11H4a.5.5 0 0 1-.485-.379L1.61 3H.5a.5.5 0 0 1-.5-.5M3.14 5l.5 2H5V5zM6 '
#  '5v2h2V5zm3 0v2h2V5zm3 0v2h1.36l.5-2zm1.11 3H12v2h.61zM11 8H9v2h2zM8 '
#  '8H6v2h2zM5 8H3.89l.5 2H5zm0 5a1 1 0 1 0 0 2 1 1 0 0 0 0-2m-2 1a2 2 0 1 1 4 0 '
#  '2 2 0 0 1-4 0m9-1a1 1 0 1 0 0 2 1 1 0 0 0 0-2m-2 1a2 2 0 1 1 4 0 2 2 0 0 1-4 '
#  '0"/>\n'
#  '                                    </svg>\n'
#  '                                    <span class="text-nowrap">Sotib '
#  'olish</span>\n'
#  '                                </button>\n'
#  '                            </div>\n'
#  '                        </div>\n'
#  '                    </div>\n'
#  '                </div>\n'
#  '\n'
#  '                <div class="col-lg-4 col-md-6 col-12">\n'
#  '                    <div class="single-feature wow fadeInUp p-4 p-md-3 '
#  'p-xl-4" data-wow-delay=".2s">\n'
#  '                        <img class="w-75 d-block mx-auto mb-4 '
#  'object-fit-cover" style="height: 180px;" '
#  'src="https://s3p.kattabozor.uz/ri/2ebeea7e4b00925ab91deff5dc425fa414b63447a2048ae109d625d224b1c249_2UFkIo_640l.jpg" '
#  'alt="monoblok_1">\n'
#  "                        <h5>Monoblok 27'' Flat</h5>\n"
#  '                        <h6>H560 (D238)</h6>\n'
#  '                        <br>\n'
#  '                        <h6 class="text-decoration-line-through '
#  'text-danger">3 900 000 so\'m</h6>\n'
#  '                        <h4 class="text-primary">3 800 000 so\'m</h4>\n'
#  '\n'
#  '                        <div class="table-content mt-3">\n'
#  '                            <ul class="table-list table-list-nth mb-3">\n'
#  '                                <li>\n'
#  '                                  <svg xmlns="http://www.w3.org/2000/svg" '
#  'width="18" height="18" fill="currentColor" class="bi bi-cpu" viewBox="0 0 16 '
#  '16">\n'
#  '                                    <path d="M5 0a.5.5 0 0 1 '
#  '.5.5V2h1V.5a.5.5 0 0 1 1 0V2h1V.5a.5.5 0 0 1 1 0V2h1V.5a.5.5 0 0 1 1 0V2A2.5 '
#  '2.5 0 0 1 14 4.5h1.5a.5.5 0 0 1 0 1H14v1h1.5a.5.5 0 0 1 0 1H14v1h1.5a.5.5 0 '
#  '0 1 0 1H14v1h1.5a.5.5 0 0 1 0 1H14a2.5 2.5 0 0 1-2.5 2.5v1.5a.5.5 0 0 1-1 '
#  '0V14h-1v1.5a.5.5 0 0 1-1 0V14h-1v1.5a.5.5 0 0 1-1 0V14h-1v1.5a.5.5 0 0 1-1 '
#  '0V14A2.5 2.5 0 0 1 2 11.5H.5a.5.5 0 0 1 0-1H2v-1H.5a.5.5 0 0 1 '
#  '0-1H2v-1H.5a.5.5 0 0 1 0-1H2v-1H.5a.5.5 0 0 1 0-1H2A2.5 2.5 0 0 1 4.5 '
#  '2V.5A.5.5 0 0 1 5 0m-.5 3A1.5 1.5 0 0 0 3 4.5v7A1.5 1.5 0 0 0 4.5 13h7a1.5 '
#  '1.5 0 0 0 1.5-1.5v-7A1.5 1.5 0 0 0 11.5 3zM5 6.5A1.5 1.5 0 0 1 6.5 5h3A1.5 '
#  '1.5 0 0 1 11 6.5v3A1.5 1.5 0 0 1 9.5 11h-3A1.5 1.5 0 0 1 5 9.5zM6.5 6a.5.5 0 '
#  '0 0-.5.5v3a.5.5 0 0 0 .5.5h3a.5.5 0 0 0 .5-.5v-3a.5.5 0 0 0-.5-.5z"/>\n'
#  '                                  </svg>\n'
#  '                                  <b>CPU:</b> Core i3-10400</li>\n'
#  '                                <li>\n'
#  '                                  <svg xmlns="http://www.w3.org/2000/svg" '
#  'width="18" height="18" fill="currentColor" class="bi bi-memory" viewBox="0 0 '
#  '16 16">\n'
#  '                                    <path d="M1 3a1 1 0 0 0-1 1v8a1 1 0 0 0 '
#  '1 1h4.586a1 1 0 0 0 .707-.293l.353-.353a.5.5 0 0 1 .708 0l.353.353a1 1 0 0 0 '
#  '.707.293H15a1 1 0 0 0 1-1V4a1 1 0 0 0-1-1zm.5 1h3a.5.5 0 0 1 .5.5v4a.5.5 0 0 '
#  '1-.5.5h-3a.5.5 0 0 1-.5-.5v-4a.5.5 0 0 1 .5-.5m5 0h3a.5.5 0 0 1 .5.5v4a.5.5 '
#  '0 0 1-.5.5h-3a.5.5 0 0 1-.5-.5v-4a.5.5 0 0 1 .5-.5m4.5.5a.5.5 0 0 1 '
#  '.5-.5h3a.5.5 0 0 1 .5.5v4a.5.5 0 0 1-.5.5h-3a.5.5 0 0 1-.5-.5zM2 '
#  '10v2H1v-2zm2 0v2H3v-2zm2 0v2H5v-2zm3 0v2H8v-2zm2 0v2h-1v-2zm2 0v2h-1v-2zm2 '
#  '0v2h-1v-2z"/>\n'
#  '                                  </svg>\n'
#  '                                  <b>RAM:</b> 8 GB</li>\n'
#  '                                <li>\n'
#  '                                  <svg xmlns="http://www.w3.org/2000/svg" '
#  'width="18" height="18" fill="currentColor" class="bi bi-nvme" viewBox="0 0 '
#  '16 16">\n'
#  '                                    <path d="M1.5 4.5A.5.5 0 0 1 2 '
#  '4h13.5a.5.5 0 0 1 .5.5V7a.5.5 0 0 1-.5.5.5.5 0 0 0 0 1 .5.5 0 0 1 '
#  '.5.5v2.5a.5.5 0 0 1-.5.5H2a.5.5 0 0 1-.5-.5h-1A.5.5 0 0 1 0 11V7.5A.5.5 0 0 '
#  '1 .5 7h1a.25.25 0 0 0 0-.5h-1A.5.5 0 0 1 0 6V5a.5.5 0 0 1 .5-.5zm1 .5a.5.5 0 '
#  '0 1-.5.5h-.5a1.25 1.25 0 1 1 0 2.5H1v2.5h1a.5.5 0 0 1 .5.5H15V9.415a1.5 1.5 '
#  '0 0 1 0-2.83V5z"/>\n'
#  '                                    <path d="M4 6.5a.5.5 0 0 1 .5-.5h2a.5.5 '
#  '0 0 1 .5.5v3a.5.5 0 0 1-.5.5h-2a.5.5 0 0 1-.5-.5zM5 7v2h1V7zm3-.5a.5.5 0 0 1 '
#  '.5-.5h4a.5.5 0 0 1 .5.5v3a.5.5 0 0 1-.5.5h-4a.5.5 0 0 1-.5-.5zM9 '
#  '7v2h3V7z"/>\n'
#  '                                  </svg>\n'
#  '                                  <b>SSD:</b> 512 GB\n'
#  '                                </li>\n'
#  '                            </ul>\n'
#  '                            <div class="d-flex justify-content-between '
#  'align-items-center gap-3">\n'
#  '                                <button data-bs-toggle="modal" '
#  'data-bs-target="#batafsilModal" class="btn btn-primary w-100 d-flex '
#  'justify-content-center align-items-center gap-2">\n'
#  '                                    <svg xmlns="http://www.w3.org/2000/svg" '
#  'width="16" height="16" fill="currentColor" class="bi bi-info-circle" '
#  'viewBox="0 0 16 16">\n'
#  '                                        <path d="M8 15A7 7 0 1 1 8 1a7 7 0 0 '
#  '1 0 14m0 1A8 8 0 1 0 8 0a8 8 0 0 0 0 16"/>\n'
#  '                                        <path d="m8.93 '
#  '6.588-2.29.287-.082.38.45.083c.294.07.352.176.288.469l-.738 '
#  '3.468c-.194.897.105 1.319.808 1.319.545 0 1.178-.252 '
#  '1.465-.598l.088-.416c-.2.176-.492.246-.686.246-.275 0-.375-.193-.304-.533zM9 '
#  '4.5a1 1 0 1 1-2 0 1 1 0 0 1 2 0"/>\n'
#  '                                    </svg>\n'
#  '                                    <span '
#  'class="text-nowrap">Batafsil</span>\n'
#  '                                </button>\n'
#  '                                <button data-bs-toggle="modal" '
#  'data-bs-target="#monoblokModal" class="btn btn-primary w-100 d-flex '
#  'justify-content-center align-items-center gap-2">\n'
#  '                                    <svg xmlns="http://www.w3.org/2000/svg" '
#  'width="16" height="16" fill="currentColor" class="bi bi-cart4" viewBox="0 0 '
#  '16 16">\n'
#  '                                        <path d="M0 2.5A.5.5 0 0 1 .5 '
#  '2H2a.5.5 0 0 1 .485.379L2.89 4H14.5a.5.5 0 0 1 .485.621l-1.5 6A.5.5 0 0 1 13 '
#  '11H4a.5.5 0 0 1-.485-.379L1.61 3H.5a.5.5 0 0 1-.5-.5M3.14 5l.5 2H5V5zM6 '
#  '5v2h2V5zm3 0v2h2V5zm3 0v2h1.36l.5-2zm1.11 3H12v2h.61zM11 8H9v2h2zM8 '
#  '8H6v2h2zM5 8H3.89l.5 2H5zm0 5a1 1 0 1 0 0 2 1 1 0 0 0 0-2m-2 1a2 2 0 1 1 4 0 '
#  '2 2 0 0 1-4 0m9-1a1 1 0 1 0 0 2 1 1 0 0 0 0-2m-2 1a2 2 0 1 1 4 0 2 2 0 0 1-4 '
#  '0"/>\n'
#  '                                    </svg>\n'
#  '                                    <span class="text-nowrap">Sotib '
#  'olish</span>\n'
#  '                                </button>\n'
#  '                            </div>\n'
#  '                        </div>\n'
#  '                    </div>\n'
#  '                </div>\n'
#  '\n'
#  '                <div class="col-lg-4 col-md-6 col-12">\n'
#  '                    <div class="single-feature wow fadeInUp p-4 p-md-3 '
#  'p-xl-4" data-wow-delay=".2s">\n'
#  '                        <img class="w-75 d-block mx-auto mb-4 '
#  'object-fit-cover" style="height: 180px;" '
#  'src="https://s3p.kattabozor.uz/ri/d969449595a949664d43db325200e265a911d1c21a42dd56fb551007d19512d8_1iEehg_640l.jpg" '
#  'alt="monoblok_1">\n'
#  "                        <h5>Monoblok 24'' Flat</h5>\n"
#  '                        <h6>H510 (D238)</h6>\n'
#  '                        <br>\n'
#  '                        <h6 class="text-decoration-line-through '
#  'text-danger">3 900 000 so\'m</h6>\n'
#  '                        <h4 class="text-primary">3 600 000 so\'m</h4>\n'
#  '\n'
#  '                        <div class="table-content mt-3">\n'
#  '                            <ul class="table-list table-list-nth mb-3">\n'
#  '                                <li>\n'
#  '                                  <svg xmlns="http://www.w3.org/2000/svg" '
#  'width="18" height="18" fill="currentColor" class="bi bi-cpu" viewBox="0 0 16 '
#  '16">\n'
#  '                                    <path d="M5 0a.5.5 0 0 1 '
#  '.5.5V2h1V.5a.5.5 0 0 1 1 0V2h1V.5a.5.5 0 0 1 1 0V2h1V.5a.5.5 0 0 1 1 0V2A2.5 '
#  '2.5 0 0 1 14 4.5h1.5a.5.5 0 0 1 0 1H14v1h1.5a.5.5 0 0 1 0 1H14v1h1.5a.5.5 0 '
#  '0 1 0 1H14v1h1.5a.5.5 0 0 1 0 1H14a2.5 2.5 0 0 1-2.5 2.5v1.5a.5.5 0 0 1-1 '
#  '0V14h-1v1.5a.5.5 0 0 1-1 0V14h-1v1.5a.5.5 0 0 1-1 0V14h-1v1.5a.5.5 0 0 1-1 '
#  '0V14A2.5 2.5 0 0 1 2 11.5H.5a.5.5 0 0 1 0-1H2v-1H.5a.5.5 0 0 1 '
#  '0-1H2v-1H.5a.5.5 0 0 1 0-1H2v-1H.5a.5.5 0 0 1 0-1H2A2.5 2.5 0 0 1 4.5 '
#  '2V.5A.5.5 0 0 1 5 0m-.5 3A1.5 1.5 0 0 0 3 4.5v7A1.5 1.5 0 0 0 4.5 13h7a1.5 '
#  '1.5 0 0 0 1.5-1.5v-7A1.5 1.5 0 0 0 11.5 3zM5 6.5A1.5 1.5 0 0 1 6.5 5h3A1.5 '
#  '1.5 0 0 1 11 6.5v3A1.5 1.5 0 0 1 9.5 11h-3A1.5 1.5 0 0 1 5 9.5zM6.5 6a.5.5 0 '
#  '0 0-.5.5v3a.5.5 0 0 0 .5.5h3a.5.5 0 0 0 .5-.5v-3a.5.5 0 0 0-.5-.5z"/>\n'
#  '                                  </svg>\n'
#  '                                  <b>CPU:</b> Core i3-10400</li>\n'
#  '                                <li>\n'
#  '                                  <svg xmlns="http://www.w3.org/2000/svg" '
#  'width="18" height="18" fill="currentColor" class="bi bi-memory" viewBox="0 0 '
#  '16 16">\n'
#  '                                    <path d="M1 3a1 1 0 0 0-1 1v8a1 1 0 0 0 '
#  '1 1h4.586a1 1 0 0 0 .707-.293l.353-.353a.5.5 0 0 1 .708 0l.353.353a1 1 0 0 0 '
#  '.707.293H15a1 1 0 0 0 1-1V4a1 1 0 0 0-1-1zm.5 1h3a.5.5 0 0 1 .5.5v4a.5.5 0 0 '
#  '1-.5.5h-3a.5.5 0 0 1-.5-.5v-4a.5.5 0 0 1 .5-.5m5 0h3a.5.5 0 0 1 .5.5v4a.5.5 '
#  '0 0 1-.5.5h-3a.5.5 0 0 1-.5-.5v-4a.5.5 0 0 1 .5-.5m4.5.5a.5.5 0 0 1 '
#  '.5-.5h3a.5.5 0 0 1 .5.5v4a.5.5 0 0 1-.5.5h-3a.5.5 0 0 1-.5-.5zM2 '
#  '10v2H1v-2zm2 0v2H3v-2zm2 0v2H5v-2zm3 0v2H8v-2zm2 0v2h-1v-2zm2 0v2h-1v-2zm2 '
#  '0v2h-1v-2z"/>\n'
#  '                                  </svg>\n'
#  '                                  <b>RAM:</b> 8 GB</li>\n'
#  '                                <li>\n'
#  '                                  <svg xmlns="http://www.w3.org/2000/svg" '
#  'width="18" height="18" fill="currentColor" class="bi bi-nvme" viewBox="0 0 '
#  '16 16">\n'
#  '                                    <path d="M1.5 4.5A.5.5 0 0 1 2 '
#  '4h13.5a.5.5 0 0 1 .5.5V7a.5.5 0 0 1-.5.5.5.5 0 0 0 0 1 .5.5 0 0 1 '
#  '.5.5v2.5a.5.5 0 0 1-.5.5H2a.5.5 0 0 1-.5-.5h-1A.5.5 0 0 1 0 11V7.5A.5.5 0 0 '
#  '1 .5 7h1a.25.25 0 0 0 0-.5h-1A.5.5 0 0 1 0 6V5a.5.5 0 0 1 .5-.5zm1 .5a.5.5 0 '
#  '0 1-.5.5h-.5a1.25 1.25 0 1 1 0 2.5H1v2.5h1a.5.5 0 0 1 .5.5H15V9.415a1.5 1.5 '
#  '0 0 1 0-2.83V5z"/>\n'
#  '                                    <path d="M4 6.5a.5.5 0 0 1 .5-.5h2a.5.5 '
#  '0 0 1 .5.5v3a.5.5 0 0 1-.5.5h-2a.5.5 0 0 1-.5-.5zM5 7v2h1V7zm3-.5a.5.5 0 0 1 '
#  '.5-.5h4a.5.5 0 0 1 .5.5v3a.5.5 0 0 1-.5.5h-4a.5.5 0 0 1-.5-.5zM9 '
#  '7v2h3V7z"/>\n'
#  '                                  </svg>\n'
#  '                                  <b>SSD:</b> 512 GB\n'
#  '                                </li>\n'
#  '                            </ul>\n'
#  '                            <div class="d-flex justify-content-between '
#  'align-items-center gap-3">\n'
#  '                                <button data-bs-toggle="modal" '
#  'data-bs-target="#batafsilModal" class="btn btn-primary w-100 d-flex '
#  'justify-content-center align-items-center gap-2">\n'
#  '                                    <svg xmlns="http://www.w3.org/2000/svg" '
#  'width="16" height="16" fill="currentColor" class="bi bi-info-circle" '
#  'viewBox="0 0 16 16">\n'
#  '                                        <path d="M8 15A7 7 0 1 1 8 1a7 7 0 0 '
#  '1 0 14m0 1A8 8 0 1 0 8 0a8 8 0 0 0 0 16"/>\n'
#  '                                        <path d="m8.93 '
#  '6.588-2.29.287-.082.38.45.083c.294.07.352.176.288.469l-.738 '
#  '3.468c-.194.897.105 1.319.808 1.319.545 0 1.178-.252 '
#  '1.465-.598l.088-.416c-.2.176-.492.246-.686.246-.275 0-.375-.193-.304-.533zM9 '
#  '4.5a1 1 0 1 1-2 0 1 1 0 0 1 2 0"/>\n'
#  '                                    </svg>\n'
#  '                                    <span '
#  'class="text-nowrap">Batafsil</span>\n'
#  '                                </button>\n'
#  '                                <button data-bs-toggle="modal" '
#  'data-bs-target="#monoblokModal" class="btn btn-primary w-100 d-flex '
#  'justify-content-center align-items-center gap-2">\n'
#  '                                    <svg xmlns="http://www.w3.org/2000/svg" '
#  'width="16" height="16" fill="currentColor" class="bi bi-cart4" viewBox="0 0 '
#  '16 16">\n'
#  '                                        <path d="M0 2.5A.5.5 0 0 1 .5 '
#  '2H2a.5.5 0 0 1 .485.379L2.89 4H14.5a.5.5 0 0 1 .485.621l-1.5 6A.5.5 0 0 1 13 '
#  '11H4a.5.5 0 0 1-.485-.379L1.61 3H.5a.5.5 0 0 1-.5-.5M3.14 5l.5 2H5V5zM6 '
#  '5v2h2V5zm3 0v2h2V5zm3 0v2h1.36l.5-2zm1.11 3H12v2h.61zM11 8H9v2h2zM8 '
#  '8H6v2h2zM5 8H3.89l.5 2H5zm0 5a1 1 0 1 0 0 2 1 1 0 0 0 0-2m-2 1a2 2 0 1 1 4 0 '
#  '2 2 0 0 1-4 0m9-1a1 1 0 1 0 0 2 1 1 0 0 0 0-2m-2 1a2 2 0 1 1 4 0 2 2 0 0 1-4 '
#  '0"/>\n'
#  '                                    </svg>\n'
#  '                                    <span class="text-nowrap">Sotib '
#  'olish</span>\n'
#  '                                </button>\n'
#  '                            </div>\n'
#  '                        </div>\n'
#  '                    </div>\n'
#  '                </div>\n'
#  '\n'
#  '            </div>\n'
#  '        </div>\n'
#  '    </section>\n'
#  '    <!--/ Monobloklar end  -->\n'
#  '\n'
#  '    <!-- Operatsion Tizimlar start -->\n'
#  '    <section id="operatsion" class="features section" style="padding-bottom: '
#  '0px;">\n'
#  '        <div class="container">\n'
#  '            <div class="row">\n'
#  '                <div class="col-12">\n'
#  '                    <div class="section-title">\n'
#  '                        <h2 style="text-transform: uppercase; color: '
#  '#3ba1e7;">Operatsion tizimlar</h2>\n'
#  "                        <p>O'zingiz uchun mos Operatsion Tizimni "
#  'tanlang!</p>\n'
#  '                    </div>\n'
#  '                </div>\n'
#  '            </div>\n'
#  '            <div class="row">\n'
#  '                <div class="col-lg-4 col-md-6 col-12">\n'
#  '                    <!-- Start Single Feature -->\n'
#  '                    <div class="single-feature wow fadeInUp" '
#  'data-wow-delay=".2s">\n'
#  '                        <!-- <i class="lni lni-windows"></i> -->\n'
#  '                        <img src="./assets/icons/icons8-windows-11-48.png" '
#  'alt="Windows-11"\n'
#  '                            style="padding-bottom: 15px; height: 60px;">\n'
#  '                        <h5>Windows 11 Home/Pro</h5>\n'
#  '                        <!-- Start Table Content -->\n'
#  '                        <div class="table-content">\n'
#  '                            <br>\n'
#  '                            <h3 class="">Nimalar ichida bor:</h3>\n'
#  '                            <!-- Table List -->\n'
#  '                            <ul class="table-list table-list-nth">\n'
#  '                                <li><i class="lni lni-circle-plus"></i> '
#  "Manzilga borib o'rnatish</li>\n"
#  '                                <li><i class="lni lni-circle-plus"></i> '
#  'Barcha drayverlar</li>\n'
#  '                                <li><i class="lni lni-circle-plus"></i> '
#  'Microsoft Office 2021</li>\n'
#  '                                <li><i class="lni lni-circle-plus"></i> '
#  'AIMP+WinRAR+PotPlayer</li>\n'
#  '                                <li style="font-style: italic; font-weight: '
#  'bold;"><i class="lni lni-cart-full"></i>\n'
#  '                                    300.000 UZS</li>\n'
#  '                                <li><i class="lni lni-phone"> </i>&nbsp;<a '
#  'href="tel:+998930091166">+998 (93) 009 11\n'
#  '                                        66</a></li>\n'
#  '                                <li><i class="lni '
#  'lni-telegram-original"></i>&nbsp;<a\n'
#  '                                        '
#  'href="https://t.me/sh_shirinboyev">Telegram</a></li>\n'
#  '                            </ul>\n'
#  '                            <!-- End Table List -->\n'
#  '                        </div>\n'
#  '                        <!-- End Table Content -->\n'
#  '                    </div>\n'
#  '                    <!-- End Single Feature -->\n'
#  '                </div>\n'
#  '                <div class="col-lg-4 col-md-6 col-12">\n'
#  '                    <!-- Start Single Feature -->\n'
#  '                    <div class="single-feature wow fadeInUp" '
#  'data-wow-delay=".4s">\n'
#  '                        <!-- <i class="lni lni-lock"></i> -->\n'
#  '                        <img src="./assets/icons/icons8-windows-10-48.png" '
#  'alt="Windows-10"\n'
#  '                            style="padding-bottom: 15px; height: 60px;">\n'
#  '                        <h5>Windows 10 Home/Pro</h5>\n'
#  '                        <!-- Start Table Content -->\n'
#  '                        <div class="table-content">\n'
#  '                            <br>\n'
#  '                            <h3 class="">Nimalar ichida bor:</h3>\n'
#  '                            <!-- Table List -->\n'
#  '                            <ul class="table-list table-list-nth">\n'
#  '                                <li><i class="lni lni-circle-plus"></i> '
#  "Manzilga borib o'rnatish</li>\n"
#  '                                <li><i class="lni lni-circle-plus"></i> '
#  'Barcha drayverlar</li>\n'
#  '                                <li><i class="lni lni-circle-plus"></i> '
#  'Microsoft Office 2021</li>\n'
#  '                                <li><i class="lni lni-circle-plus"></i> '
#  'AIMP+WinRAR+PotPlayer</li>\n'
#  '                                <li style="font-style: italic; font-weight: '
#  'bold;"><i class="lni lni-cart-full"></i>\n'
#  '                                    250.000 UZS</li>\n'
#  '                                <li><i class="lni lni-phone"> </i>&nbsp;<a '
#  'href="tel:+998930091166">+998 (93) 009 11\n'
#  '                                        66</a></li>\n'
#  '                                <li><i class="lni '
#  'lni-telegram-original"></i>&nbsp;<a\n'
#  '                                        '
#  'href="https://t.me/sh_shirinboyev">Telegram</a></li>\n'
#  '                            </ul>\n'
#  '                            <!-- End Table List -->\n'
#  '                        </div>\n'
#  '                        <!-- End Table Content -->\n'
#  '                    </div>\n'
#  '                    <!-- End Single Feature -->\n'
#  '                </div>\n'
#  '                <div class="col-lg-4 col-md-6 col-12">\n'
#  '                    <!-- Start Single Feature -->\n'
#  '                    <div class="single-feature wow fadeInUp" '
#  'data-wow-delay=".4s">\n'
#  '                        <!-- <i class="lni lni-lock"></i> -->\n'
#  '                        <img src="./assets/icons/icons8-windows-10-48.png" '
#  'alt="Windows-8.1"\n'
#  '                            style="padding-bottom: 15px; height: 60px;">\n'
#  '                        <h5>Windows 8.1 Pro/Enterprise</h5>\n'
#  '                        <!-- Start Table Content -->\n'
#  '                        <div class="table-content">\n'
#  '                            <br>\n'
#  '                            <h3 class="">Nimalar ichida bor:</h3>\n'
#  '                            <!-- Table List -->\n'
#  '                            <ul class="table-list table-list-nth">\n'
#  '                                <li><i class="lni lni-circle-plus"></i> '
#  "Manzilga borib o'rnatish</li>\n"
#  '                                <li><i class="lni lni-circle-plus"></i> '
#  'Barcha drayverlar</li>\n'
#  '                                <li><i class="lni lni-circle-plus"></i> '
#  'Microsoft Office 2016/2019</li>\n'
#  '                                <li><i class="lni lni-circle-plus"></i> '
#  'AIMP+WinRAR+PotPlayer</li>\n'
#  '                                <li style="font-style: italic; font-weight: '
#  'bold;"><i class="lni lni-cart-full"></i>\n'
#  '                                    250.000 UZS</li>\n'
#  '                                <li><i class="lni lni-phone"> </i>&nbsp;<a '
#  'href="tel:+998930091166">+998 (93) 009 11\n'
#  '                                        66</a></li>\n'
#  '                                <li><i class="lni '
#  'lni-telegram-original"></i>&nbsp;<a\n'
#  '                                        '
#  'href="https://t.me/sh_shirinboyev">Telegram</a></li>\n'
#  '                            </ul>\n'
#  '                            <!-- End Table List -->\n'
#  '                        </div>\n'
#  '                        <!-- End Table Content -->\n'
#  '                    </div>\n'
#  '                    <!-- End Single Feature -->\n'
#  '                </div>\n'
#  '                <div class="col-lg-4 col-md-6 col-12">\n'
#  '                    <!-- Start Single Feature -->\n'
#  '                    <div class="single-feature wow fadeInUp" '
#  'data-wow-delay=".4s">\n'
#  '                        <!-- <i class="lni lni-lock"></i> -->\n'
#  '                        <img src="./assets/icons/icons8-windows-xp-48.png" '
#  'alt="Windows-7"\n'
#  '                            style="padding-bottom: 15px; height: 60px;">\n'
#  '                        <h5>Windows 7 Home/Professional</h5>\n'
#  '                        <!-- Start Table Content -->\n'
#  '                        <div class="table-content">\n'
#  '                            <br>\n'
#  '                            <h3 class="">Nimalar ichida bor:</h3>\n'
#  '                            <!-- Table List -->\n'
#  '                            <ul class="table-list table-list-nth">\n'
#  '                                <li><i class="lni lni-circle-plus"></i> '
#  "Manzilga borib o'rnatish</li>\n"
#  '                                <li><i class="lni lni-circle-plus"></i> '
#  'Barcha drayverlar</li>\n'
#  '                                <li><i class="lni lni-circle-plus"></i> '
#  'Microsoft Office 2010/2013</li>\n'
#  '                                <li><i class="lni lni-circle-plus"></i> '
#  'AIMP+WinRAR+PotPlayer</li>\n'
#  '                                <li style="font-style: italic; font-weight: '
#  'bold;"><i class="lni lni-cart-full"></i>\n'
#  '                                    250.000 UZS</li>\n'
#  '                                <li><i class="lni lni-phone"> </i>&nbsp;<a '
#  'href="tel:+998930091166">+998 (93) 009 11\n'
#  '                                        66</a></li>\n'
#  '                                <li><i class="lni '
#  'lni-telegram-original"></i>&nbsp;<a\n'
#  '                                        '
#  'href="https://t.me/sh_shirinboyev">Telegram</a></li>\n'
#  '                            </ul>\n'
#  '                            <!-- End Table List -->\n'
#  '                        </div>\n'
#  '                        <!-- End Table Content -->\n'
#  '                    </div>\n'
#  '                    <!-- End Single Feature -->\n'
#  '                </div>\n'
#  '                <div class="col-lg-4 col-md-6 col-12">\n'
#  '                    <!-- Start Single Feature -->\n'
#  '                    <div class="single-feature wow fadeInUp" '
#  'data-wow-delay=".6s">\n'
#  '                        <!-- <i class="lni lni-reload"></i> -->\n'
#  '                        <img src="./assets/icons/icons8-ubuntu-48.png" '
#  'alt="Ubuntu-Desktop"\n'
#  '                            style="padding-bottom: 15px; height: 60px;">\n'
#  '                        <h5>Ubuntu 22.04 Desktop/Server</h5>\n'
#  '                        <!-- Start Table Content -->\n'
#  '                        <div class="table-content">\n'
#  '                            <br>\n'
#  '                            <h3 class="">Nimalar ichida bor:</h3>\n'
#  '\n'
#  '                            <!-- Table List -->\n'
#  '                            <ul class="table-list table-list-nth">\n'
#  '                                <li><i class="lni lni-circle-plus"></i> '
#  "Manzilga borib o'rnatish</li>\n"
#  '                                <li><i class="lni lni-circle-plus"></i> '
#  'Barcha drayverlar</li>\n'
#  '                                <li><i class="lni lni-circle-plus"></i> '
#  'Telegram Desktop</li>\n'
#  '                                <li><i class="lni lni-circle-plus"></i> '
#  'Google Chrome Browser</li>\n'
#  '                                <li style="font-style: italic; font-weight: '
#  'bold;"><i class="lni lni-cart-full"></i>\n'
#  '                                    200.000 UZS</li>\n'
#  '                                <li><i class="lni lni-phone"> </i>&nbsp;<a '
#  'href="tel:+998930091166">+998 (93) 009 11\n'
#  '                                        66</a></li>\n'
#  '                                <li><i class="lni '
#  'lni-telegram-original"></i>&nbsp;<a\n'
#  '                                        '
#  'href="https://t.me/sh_shirinboyev">Telegram</a></li>\n'
#  '                            </ul>\n'
#  '                            <!-- End Table List -->\n'
#  '                        </div>\n'
#  '                        <!-- End Table Content -->\n'
#  '                    </div>\n'
#  '                    <!-- End Single Feature -->\n'
#  '                </div>\n'
#  '                <div class="col-lg-4 col-md-6 col-12">\n'
#  '                    <!-- Start Single Feature -->\n'
#  '                    <div class="single-feature wow fadeInUp" '
#  'data-wow-delay=".6s">\n'
#  '                        <!-- <i class="lni lni-reload"></i> -->\n'
# ...
#  'src="./assets/free-soft-icons/winrar.png" alt="img" '
#  'draggable="false"></div>\n'
#  '                        <h6>WinRAR</h6>\n'
#  '                        <a '
#  'href="https://free-softs.netlify.app/softs/part_1/WinRAR.v7.01.zip" '
#  'class="btn1">Yuklab Olish</a>\n'
#  '                    </li>\n'
#  '\n'
#  '                    <li class="card">\n'
#  '                        <div class="img"><img '
#  'src="./assets/free-soft-icons/aimp.ico" alt="img" draggable="false"></div>\n'
#  '                        <h6>AIMP</h6>\n'
#  '                        <a '
#  'href="https://free-softs.netlify.app/softs/part_1/aimp_5.30.2560_w32.exe" '
#  'class="btn1">Yuklab Olish</a>\n'
#  '                    </li>\n'
#  '\n'
#  '                    <li class="card">\n'
#  '                        <div class="img"><img '
#  'src="./assets/free-soft-icons/PotPlayer-.png" alt="img" draggable="false"> '
#  '</div>\n'
#  '                        <h6>PotPlayer</h6>\n'
#  '                        <a '
#  'href="https://free-softs.netlify.app/softs/part_1/potplayer-x86_240618.exe" '
#  'class="btn1">Yuklab Olish</a>\n'
#  '                    </li>\n'
#  '\n'
#  '                    <li class="card">\n'
#  '                        <div class="img"><img '
#  'src="./assets/free-soft-icons/TrafficMonitor.70x70Logo.png" alt="img" '
#  'draggable="false"></div>\n'
#  '                        <h6>TrafficMonitor</h6>\n'
#  '                        <a '
#  'href="https://free-softs.netlify.app/softs/part_1/TrafficMonitor_V1.84.1_x64.zip" '
#  'class="btn1">Yuklab Olish</a>\n'
#  '                    </li>\n'
#  '\n'
#  '                    <li class="card">\n'
#  '                        <div class="img"><img '
#  'src="./assets/free-soft-icons/wub.png" alt="img" draggable="false"></div>\n'
#  '                        <h6>WUB</h6>\n'
#  '                        <a '
#  'href="https://free-softs.netlify.app/softs/part_1/Wub.zip" '
#  'class="btn1">Yuklab Olish</a>\n'
#  '                    </li>\n'
#  '\n'
#  '                    <li class="card">\n'
#  '                        <div class="img"><img '
#  'src="./assets/free-soft-icons/Firewall-App-Blocker.png" alt="img" '
#  'draggable="false"></div>\n'
#  '                        <h6>FAB</h6>\n'
#  '                        <a '
#  'href="https://free-softs.netlify.app/softs/part_1/fab.zip" '
#  'class="btn1">Yuklab Olish</a>\n'
#  '                    </li>\n'
#  '\n'
#  '                    <li class="card">\n'
#  '                        <div class="img"><img '
#  'src="./assets/free-soft-icons/image-removebg-preview.png" alt="img" '
#  'draggable="false"></div>\n'
#  '                        <h6>SimpleWall</h6>\n'
#  '                        <a '
#  'href="https://free-softs.netlify.app/softs/part_1/simplewall-3.8.2-setup.exe" '
#  'class="btn1">Yuklab Olish</a>\n'
#  '                    </li>\n'
#  '\n'
#  '                    <li class="card">\n'
#  '                        <div class="img"><img '
#  'src="./assets/free-soft-icons/MemReduct200-175.png" alt="img" '
#  'draggable="false"></div>\n'
#  '                        <h6>Mem Reduct</h6>\n'
#  '                        <a '
#  'href="https://free-softs.netlify.app/softs/part_1/memreduct-3.4-setup.exe" '
#  'class="btn1">Yuklab Olish</a>\n'
#  '                    </li>\n'
#  '\n'
#  '                    <li class="card">\n'
#  '                        <div class="img"><img '
#  'src="./assets/free-soft-icons/idm.webp" alt="img" draggable="false"></div>\n'
#  '                        <h6>IDM</h6>\n'
#  '                        <a '
#  'href="https://free-softs.netlify.app/softs/part_1/Internet.Download.Manager.v6.42.17.zip" '
#  'class="btn1">Yuklab Olish</a>\n'
#  '                    </li>\n'
#  '\n'
#  '                    <li class="card">\n'
#  '                        <div class="img"><img '
#  'src="./assets/free-soft-icons/torrent.svg" alt="img" '
#  'draggable="false"></div>\n'
#  '                        <h6>ÂµTorrent</h6>\n'
#  '                        <a '
#  'href="https://free-softs.netlify.app/softs/part_1/uTorrent.v3.5.5.46552.zip" '
#  'class="btn1">Yuklab Olish</a>\n'
#  '                    </li>\n'
#  '\n'
#  '                    <li class="card">\n'
#  '                        <div class="img"><img '
#  'src="./assets/free-soft-icons/logo-Anydesk-400x400.png" alt="img" '
#  'draggable="false"></div>\n'
#  '                        <h6>AnyDesk v6.1</h6>\n'
#  '                        <a '
#  'href="https://free-softs.netlify.app/softs/part_1/AnyDesk%20v6.1.5.exe" '
#  'class="btn1">Yuklab Olish</a>\n'
#  '                    </li>\n'
#  '\n'
#  '                    <li class="card">\n'
#  '                        <div class="img"><img '
#  'src="./assets/free-soft-icons/logo-Anydesk-400x400.png" alt="img" '
#  'draggable="false"></div>\n'
#  '                        <h6>AnyDesk v8.0</h6>\n'
#  '                        <a '
#  'href="https://free-softs.netlify.app/softs/part_1/AnyDesk.exe" '
#  'class="btn1">Yuklab Olish</a>\n'
#  '                    </li>\n'
#  '\n'
#  '                    <li class="card">\n'
#  '                        <div class="img"><img '
#  'src="./assets/free-soft-icons/285_anydesk.png" alt="img" '
#  'draggable="false"></div>\n'
#  '                        <h6>AnyDesk v3.4</h6>\n'
#  '                        <a '
#  'href="https://free-softs.netlify.app/softs/part_1/AnyDesk%20v3.4.0.exe" '
#  'class="btn1">Yuklab Olish</a>\n'
#  '                    </li>\n'
#  '\n'
#  '                    <li class="card">\n'
#  '                        <div class="img"><img '
#  'src="./assets/free-soft-icons/Ammyy-Admin-Â©-DownLoadLy.iR_.png" alt="img" '
#  'draggable="false"></div>\n'
#  '                        <h6>Ammyy Admin 3.5</h6>\n'
#  '                        <a '
#  'href="https://free-softs.netlify.app/softs/part_1/Ammyy%20Admin%203.5.exe" '
#  'class="btn1">Yuklab Olish</a>\n'
#  '                    </li>\n'
#  '\n'
#  '                    <li class="card">\n'
#  '                        <div class="img"><img '
#  'src="./assets/free-soft-icons/Reg-Organizer.png" alt="img" '
#  'draggable="false"></div>\n'
#  '                        <h6>Reg Organizer 8.44</h6>\n'
#  '                        <a '
#  'href="https://free-softs.netlify.app/softs/part_1/Reg%20Organizer%208.44.zip" '
#  'class="btn1">Yuklab Olish</a>\n'
#  '                    </li>\n'
#  '\n'
#  '                    <li class="card">\n'
#  '                        <div class="img"><img '
#  'src="./assets/free-soft-icons/KMSAuto-Lite.png" alt="img" '
#  'draggable="false"></div>\n'
#  '                        <h6>KMS Tools</h6>\n'
#  '                        <a '
#  'href="https://free-softs.netlify.app/softs/part_2/Activator%20-%20Windows%20[%20xp,%207,%208,%208.1,%2010%20].zip" '
#  'class="btn1">Yuklab Olish</a>\n'
#  '                    </li>\n'
#  '\n'
#  '                    <li class="card">\n'
#  '                        <div class="img"><img '
#  'src="./assets/free-soft-icons/mas-what-todo-next.png" alt="img" '
#  'draggable="false"></div>\n'
#  '                        <h6>KMS/MAS/HWID</h6>\n'
#  '                        <a '
#  'href="https://free-softs.netlify.app/softs/part_2/KMS%20MAS%20HWID%20-%20Windows%2011-10%20MS-Office.zip" '
#  'class="btn1">Yuklab Olish</a>\n'
#  '                    </li>\n'
#  '\n'
#  '                    <li class="card">\n'
#  '                        <div class="img"><img '
#  'src="./assets/free-soft-icons/WindowsRegistry.png" alt="img" '
#  'draggable="false"></div>\n'
#  '                        <h6>Fast AnimEffects</h6>\n'
#  '                        <a '
#  'href="https://free-softs.netlify.app/softs/part_2/Fast%20Animations%20by%20Registry%20Changes.zip" '
#  'class="btn1">Yuklab Olish</a>\n'
#  '                    </li>\n'
#  '\n'
#  '                    <li class="card">\n'
#  '                        <div class="img"><img '
#  'src="./assets/free-soft-icons/defender_control-220x162.png" alt="img" '
#  'draggable="false"></div>\n'
#  '                        <h6>Defender Control</h6>\n'
#  '                        <a '
#  'href="https://free-softs.netlify.app/softs/part_2/Defender_Settings.zip" '
#  'class="btn1">Yuklab Olish</a>\n'
#  '                    </li>\n'
#  '\n'
#  '                    <li class="card">\n'
#  '                        <div class="img"><img '
#  'src="./assets/free-soft-icons/EaseUS_Data_Recovery_Wizard_Logo.png" '
#  'alt="img" draggable="false"></div>\n'
#  '                        <h6>EaseUS Data Recovery </h6>\n'
#  '                        <a '
#  'href="https://free-softs.netlify.app/softs/part_2/EaseUS%20Data%20Recovery%20Wizard%20TE%2014.2.1.zip" '
#  'class="btn1">Yuklab Olish</a>\n'
#  '                    </li>\n'
#  '\n'
#  '                    <li class="card">\n'
#  '                        <div class="img"><img '
#  'src="./assets/free-soft-icons/IObit_Driver_Booster.png" alt="img" '
#  'draggable="false"></div>\n'
#  '                        <h6>IObit Driver Booster</h6>\n'
#  '                        <a '
#  'href="https://free-softs.netlify.app/softs/part_2/IObit.Driver.Booster.exe" '
#  'class="btn1">Yuklab Olish</a>\n'
#  '                    </li>\n'
#  '\n'
#  '                    <li class="card">\n'
#  '                        <div class="img"><img '
#  'src="./assets/free-soft-icons/imgingest-5062326731788772877.webp" alt="img" '
#  'draggable="false"></div>\n'
#  '                        <h6>Driver Easy</h6>\n'
#  '                        <a '
#  'href="https://free-softs.netlify.app/softs/part_2/Driver.Easy.exe" '
#  'class="btn1">Yuklab Olish</a>\n'
#  '                    </li>\n'
#  '\n'
#  '                    <li class="card">\n'
#  '                        <div class="img"><img '
#  'src="./assets/free-soft-icons/iu9_icon_96_552.png" alt="img" '
#  'draggable="false"></div>\n'
#  '                        <h6>IObit Uninstaller</h6>\n'
#  '                        <a '
#  'href="https://free-softs.netlify.app/softs/part_2/iobit%20uninstaller%209.2.0.16.zip" '
#  'class="btn1">Yuklab Olish</a>\n'
#  '                    </li>\n'
#  '\n'
#  '                    <li class="card">\n'
#  '                        <div class="img"><img '
#  'src="./assets/free-soft-icons/0x0.png" alt="img" draggable="false"></div>\n'
#  '                        <h6>AOMEI Partition Assistant</h6>\n'
#  '                        <a '
#  'href="https://free-softs.netlify.app/softs/part_2/AOMEI%20Partition%20Assistant%20Pro%209.8.0.zip" '
#  'class="btn1">Yuklab Olish</a>\n'
#  '                    </li>\n'
#  '\n'
#  '                    <li class="card">\n'
#  '                        <div class="img"><img '
#  'src="./assets/free-soft-icons/videodownloader.a855bb9dddb2.svg" alt="img" '
#  'draggable="false"></div>\n'
#  '                        <h6>4K Video Downloader</h6>\n'
#  '                        <a '
#  'href="https://free-softs.netlify.app/softs/part_2/4K.Video.DownloaderPlus.v1.8.2.0111.zip" '
#  'class="btn1">Yuklab Olish</a>\n'
#  '                    </li>\n'
#  '\n'
#  '                    <li class="card">\n'
#  '                        <div class="img"><img '
#  'src="./assets/free-soft-icons/Edge_blocker-1.png" alt="img" '
#  'draggable="false"></div>\n'
#  '                        <h6>Edge Blocker</h6>\n'
#  '                        <a '
#  'href="https://free-softs.netlify.app/softs/part_2/EdgeBlock.zip" '
#  'class="btn1">Yuklab Olish</a>\n'
#  '                    </li>\n'
#  '\n'
#  '                    <li class="card">\n'
#  '                        <div class="img"><img '
#  'src="./assets/free-soft-icons/3971054-200.png" alt="img" '
#  'draggable="false"></div>\n'
#  '                        <h6>Intel VMD Drivers</h6>\n'
#  '                        <a '
#  'href="https://free-softs.netlify.app/softs/part_2/Intel%20VMD%20Driver.zip" '
#  'class="btn1">Yuklab Olish</a>\n'
#  '                    </li>\n'
#  '\n'
#  '                    <li class="card">\n'
#  '                        <div class="img"><img '
#  'src="./assets/free-soft-icons/unnamed.png" alt="img" draggable="false"> '
#  '</div>\n'
#  '                        <h6>AIDA64</h6>\n'
#  '                        <a '
#  'href="https://free-softs.netlify.app/softs/part_2/AIDA64%206.70.6000.zip" '
#  'class="btn1">Yuklab Olish</a>\n'
#  '                    </li>\n'
#  '\n'
#  '                    <li class="card">\n'
#  '                        <div class="img"><img '
#  'src="./assets/free-soft-icons/logo.png" alt="img" draggable="false"></div>\n'
#  '                        <h6>Lotin-Kiril</h6>\n'
#  '                        <a '
#  'href="https://free-softs.netlify.app/softs/part_2/KIRIL-LOTIN.exe" '
#  'class="btn1">Yuklab Olish</a>\n'
#  '                    </li>\n'
#  '\n'
#  '                    <li class="card">\n'
#  '                        <div class="img"><img '
#  'src="./assets/free-soft-icons/ventoy.png" alt="img" draggable="false"> '
#  '</div>\n'
#  '                        <h6>Ventoy v1.0.96</h6>\n'
#  '                        <a '
#  'href="https://free-softs.netlify.app/softs/part_2/ventoy-1.0.99-windows.zip" '
#  'class="btn1">Yuklab Olish</a>\n'
#  '                    </li>\n'
#  '\n'
#  '                    <li class="card">\n'
#  '                        <div class="img"><img '
#  'src="./assets/free-soft-icons/converter_office.webp" alt="img" '
#  'draggable="false"> </div>\n'
#  '                        <h6>Office Extension Lotin&Krill</h6>\n'
#  '                        <a '
#  'href="https://free-softs.netlify.app/softs/part_2/Convertor%20LOTIN&KRILL.zip" '
#  'class="btn1">Yuklab Olish</a>\n'
#  '                    </li>\n'
#  '                </ul>\n'
#  '                <i id="right" class="fa-solid fa-angle-right"></i>\n'
#  '            </div>\n'
#  '        </div>\n'
#  '    </section>\n'
#  '    <!-- Bepul Dasturlar end -->\n'
#  '\n'
#  '    <!-- Start Footer -->\n'
#  '    <footer class="footer">\n'
#  '        <!-- Start Footer Top -->\n'
#  '            <div class="container text-center py-4 py-md-5">\n'
#  '                    <div class="logo">\n'
#  '                        <a href="index.html">\n'
#  '                            <img src="assets/images/logo/white.svg" '
#  'alt="logo" style="width: 160px;">\n'
#  '                        </a>\n'
#  '                    </div>\n'
#  '                    <p class="text-muted mt-2" style="font-size: 12px;">Â© '
#  'OS//Services 2025. Barcha huquqlar himoyalangan.</p>\n'
#  '            </div>\n'
#  '        <!--/ End Footer Top -->\n'
#  '    </footer>\n'
#  '    <!--/ End Footer -->\n'
#  '\n'
#  '    <!-- ========================= scroll-top ========================= -->\n'
#  '    <a href="#" class="scroll-top">\n'
#  '        <i class="lni lni-chevron-up"></i>\n'
#  '    </a>\n'
#  '\n'
#  '    <!-- ========================= JS here start ========================= '
#  '-->\n'
#  '    <script src="assets/js/bootstrap.min.js"></script>\n'
#  '    <script src="assets/js/wow.min.js"></script>\n'
#  '    <script src="assets/js/tiny-slider.js"></script>\n'
#  '    <script src="assets/js/glightbox.min.js"></script>\n'
#  '    <script src="assets/js/count-up.min.js"></script>\n'
#  '    <script src="assets/js/main.js"></script>\n'
#  '    <script src="assets/js/wrapper.js"></script>\n'
#  '\n'
#  '    <script>\n'
#  '        //====== counter up\n'
#  '        var cu = new counterUp({\n'
#  '            start: 0,\n'
#  '            duration: 2000,\n'
#  '            intvalues: true,\n'
#  '            interval: 100,\n'
#  '            append: " ",\n'
#  '        });\n'
#  '        cu.start();\n'
#  '\n'
#  '        // use carusel\n'
#  "        var myCarousel = document.querySelector('#myCarousel')\n"
#  '        var carousel = new bootstrap.Carousel(myCarousel)\n'
#  '    </script>\n'
#  '\n'
#  '    <script '
#  'src="https://unpkg.com/inputmask@5.0.8/dist/inputmask.min.js"></script>\n'
#  '    <script>\n'
#  "        const input = document.getElementById('exampleInputNumber');\n"
#  '\n'
#  '        Inputmask("99 999 99 99", {\n'
#  '            placeholder: "-",              // boâ\x80\x98sh joylar uchun '
#  'chiziq\n'
#  '            showMaskOnHover: false,        // ustiga olib borganda mask '
#  'koâ\x80\x98rinmasin\n'
#  '            showMaskOnFocus: true,         // faqat yozayotganda '
#  'koâ\x80\x98rinadi\n'
#  '            clearIncomplete: true,         // toâ\x80\x98liq kiritilmasa, '
#  'input tozalanadi\n'
#  '        }).mask(input);\n'
#  '    </script>\n'
#  '\n'
#  '    <script src="./assets/js/telegramBotAPI.js"></script>\n'
#  '    <!-- ========================= JS here end ========================= '
#  '-->\n'
#  '</body>\n'
#  '\n'
#  '</html>')

# %%
import requests
from pprint import pprint

# restcountries API
country = 'Uzbekistan'
url = f"https://restcountries.com/v3.1/name/{country}"

r = requests.get(url)
r_json = r.json()[0]

# pprint(r_json.keys())
pprint(r_json['borders'])
# Out:
# ['AFG', 'KAZ', 'KGZ', 'TJK', 'TKM']
